# %%
import pandas as pd

# %%
PD= pd.ExcelFile("C:/Users/LENOVO/Downloads/ipl auction dataset (3).xlsx")
print(PD.sheet_names)
# Out:
# ['Personal Details', 'Base Price', 'Nationality']

# %%
PersonalDetails= PD.parse('Personal Details')
PersonalDetails
# Out:
#     Player ID  Jersy No       PLAYER NAME        ROLES  Batting Rating  \
# 0    IPL00132       56.0     Deepak Hooda  ALL-ROUNDER            79.0
# 1    IPL00163       19.0   DINESH KARTHIK       BAT/WK            82.0
# 2    IPL00165       89.0      Umran Malik      bowlers             4.0
# 3    IPL00136       23.0  DEVDUTT PADIKAL          BAT            75.0
# 4    IPL00207        3.0  Mitchell Marsh   All-Rounder            64.0
# ..        ...        ...              ...          ...             ...
# 112  IPL00197       47.0     DWAYNE BRAVO  ALL ROUNDER            71.0
# 113  IPL00223        5.0      YUZI.CHAHAL         BOWL            31.0
# 114  IPL00220       17.0   A.B.DEVILLIERS          BAT            90.0
# 115  IPL00234       47.0    GLENN MAXWELL  ALL ROUNDER            83.0
# 116  IPL00250       18.0   KANE WILIAMSON      BATSMEN            84.0
#
#      Bowling Rating  Fielding Rating  Stamina  Concentration  Agility  \
# ...

# %%
data.loc[data['Player ID']=='IPL00229']
# Out:
#    Player ID  Jersy No  PLAYER NAME       ROLES  Batting Rating  \
# 28  IPL00229       33.0  Sam Curran  ALLROUNDER            85.0
#
#     Bowling Rating  Fielding Rating  Stamina  Concentration  Agility  \
# 28            85.0             75.0     57.0           93.0     55.0
#
#     Heart rate   BMI base price Nationality  Sum_of_Rating
# 28        75.0  21.0       100L     England          245.0

# %%
Nationality= PD.parse('Nationality')
Nationality
# Out:
#     Player ID  Nationality
# 0    IPL00198   Afganistan
# 1    IPL00166    Australia
# 2    IPL00181    Australia
# 3    IPL00206    Australia
# 4    IPL00151    Australia
# ..        ...          ...
# 112  IPL00197  West Indies
# 113  IPL00124  West Indies
# 114  IPL00227  West Indies
# 115  IPL00196  West Indies
# 116  IPL00208  West Indies
#
# [117 rows x 2 columns]

# %%
BasePrice= PD.parse('Base Price')
BasePrice
# Out:
#     Player ID base price
# 0    IPL00175       100L
# 1    IPL00122       100L
# 2    IPL00217       100L
# 3    IPL00149       100L
# 4    IPL00205       100L
# ..        ...        ...
# 113  IPL00132       100L
# 114  IPL00162       100L
# 115  IPL00151       100L
# 116  IPL00148       100L
# 117  IPL00250       100L
#
# [118 rows x 2 columns]

# %%
d=pd.merge(PersonalDetails,BasePrice)
data=pd.merge(d,Nationality)
data
# Out:
#     Player ID  Jersy No       PLAYER NAME        ROLES  Batting Rating  \
# 0    IPL00132       56.0     Deepak Hooda  ALL-ROUNDER            79.0
# 1    IPL00163       19.0   DINESH KARTHIK       BAT/WK            82.0
# 2    IPL00165       89.0      Umran Malik      bowlers             4.0
# 3    IPL00136       23.0  DEVDUTT PADIKAL          BAT            75.0
# 4    IPL00207        3.0  Mitchell Marsh   All-Rounder            64.0
# ..        ...        ...              ...          ...             ...
# 113  IPL00197       47.0     DWAYNE BRAVO  ALL ROUNDER            71.0
# 114  IPL00223        5.0      YUZI.CHAHAL         BOWL            31.0
# 115  IPL00220       17.0   A.B.DEVILLIERS          BAT            90.0
# 116  IPL00234       47.0    GLENN MAXWELL  ALL ROUNDER            83.0
# 117  IPL00250       18.0   KANE WILIAMSON      BATSMEN            84.0
#
#      Bowling Rating  Fielding Rating  Stamina  Concentration  Agility  \
# ...

# %%
data.drop_duplicates(['Player ID'],inplace=True)

# %%
data['Sum_of_Rating'] = data.iloc[0:,4:7].sum(axis = 1)

# %%
data.isnull().sum()
# Out:
# Player ID          0
# Jersy No           0
# PLAYER NAME        0
# ROLES              0
# Batting Rating     0
# Bowling Rating     0
# Fielding Rating    0
# Stamina            0
# Concentration      0
# Agility            0
# Heart rate         0
# BMI                0
# base price         0
# Nationality        0
# Sum_of_Rating      0
# dtype: int64

# %%
data.Sum_of_Rating.describe()
# Out:
# count    117.000000
# mean     193.589744
# std       30.459740
# min      115.000000
# 25%      170.000000
# 50%      193.000000
# 75%      215.000000
# max      268.000000
# Name: Sum_of_Rating, dtype: float64

# %%
data.ROLES.unique()
# Out:
# array(['ALL-ROUNDER', 'BAT/WK', 'bowlers', 'BAT', 'All-Rounder', 'bowler',
#        'batsman ', 'BOWLER SPIN', 'All-Rounders', 'ALL ROUNDER',
#        'Batsman', 'BOWL', 'Bowler spin', 'BATSMAN', 'ALLROUNDER',
#        'BOWLER FA', 'BATSMEN'], dtype=object)

# %%
#data.fillna("50L",inplace=True)

# %%
data.replace('ALL-ROUNDER','ALLROUNDER',inplace=True)
data.replace('All-Rounder','ALLROUNDER',inplace=True)
data.replace('All-Rounders','ALLROUNDER',inplace=True)
data.replace('ALL ROUNDER','ALLROUNDER',inplace=True)

# %%
data.replace('bowlers','Bowlers',inplace=True)
data.replace('bowler','Bowlers',inplace=True)
data.replace('BOWL','Bowlers',inplace=True)
data.replace('BOWLER FA','Bowlers',inplace=True)
data.replace('batsman','Bowlers',inplace=True)

# %%
data.replace('BAT','Batsman',inplace=True)
data.replace('batsman','Batsman',inplace=True)
data.replace('BATSMAN','Batsman',inplace=True)
data.replace('BATSMEN','Batsman',inplace=True)

# %%
data.replace('BOWLER SPIN','Bowlerspin',inplace=True)
data.replace('Bowler spin','Bowlerspin',inplace=True)

# %%
bs=data[data.ROLES=='Bowlerspin']
Bows= bs.sort_values(['Sum_of_Rating',], ascending=[False])
Bows
# Out:
#    Player ID  Jersy No           PLAYER NAME       ROLES  Batting Rating  \
# 22  IPL00130       23.0     Mitchell Santner  Bowlerspin            78.0
# 41  IPL00171       98.0   Wanindu Hasaranga   Bowlerspin            69.0
# 70  IPL00193       77.0        Ravi Bishnoi   Bowlerspin            39.0
# 7   IPL00127       76.0         Rahul Chahar  Bowlerspin            51.0
# 82  IPL00204       78.0   Maheesh Theekshana  Bowlerspin            56.0
# 36  IPL00148       43.0          Karn Sharma  Bowlerspin            47.0
# 55  IPL00128       54.0           Adam Zampa  Bowlerspin            26.0
# 65  IPL00175       56.0            K.Gowtham  Bowlerspin            65.0
# 68  IPL00233      456.0         Rahul Sharma  Bowlerspin            59.0
# 85  IPL00188       99.0          Imran Tahir  Bowlerspin             1.0
#
#     Bowling Rating  Fielding Rating  Stamina  Concentration  Agility  \
# 22            78.0             88.0     51.0           79.0     61.0
# ...

# %%
b=data[data.ROLES=='Batsman']
Bat= b.sort_values(['Sum_of_Rating'], ascending=[False])
Bat
# Out:
#     Player ID  Jersy No         PLAYER NAME    ROLES  Batting Rating  \
# 10   IPL00173        3.0       SURESH RAINA  Batsman            91.0
# 100  IPL00178       13.0       FAF DUPLESIS  Batsman            86.0
# 58   IPL00189       45.0       ROHIT SHARMA  Batsman            90.0
# 51   IPL00202        2.0       Nitish Rana   Batsman            74.0
# 17   IPL00208        9.0        CHRIS GAYLE  Batsman            90.0
# 102  IPL00155      888.0      Kedar Jadhav   Batsman            77.0
# 112  IPL00158       23.0       SHREYAS IYER  Batsman            90.0
# 87   IPL00169       18.0        VIRAT KOHLI  Batsman            92.0
# 115  IPL00220       17.0     A.B.DEVILLIERS  Batsman            90.0
# 98   IPL00170       78.0     Shahrukh Khan   Batsman            72.0
# 42   IPL00211       45.0   Yashasvi Jaiswal  Batsman            78.0
# 83   IPL00235       88.0  SURYA KUMAR YADAV  Batsman            89.0
# 88   IPL00210       51.0       DAVID WARNER  Batsman            90.0
# ...

# %%
A=data[data.ROLES=='ALLROUNDER']
All= A.sort_values(['Sum_of_Rating'], ascending=[False])
All
# Out:
#     Player ID  Jersy No              PLAYER NAME       ROLES  Batting Rating  \
# 54   IPL00159        8.0                R.JADEJA  ALLROUNDER            86.0
# 40   IPL00217       55.0               K.POLLARD  ALLROUNDER            90.0
# 16   IPL00231       22.0                H.PANDYA  ALLROUNDER            89.0
# 108  IPL00181        5.0          Marcus Stoinis  ALLROUNDER            83.0
# 84   IPL00184       55.0               Moeen Ali  ALLROUNDER            89.0
# 28   IPL00229       33.0              Sam Curran  ALLROUNDER            85.0
# 19   IPL00198       99.0             RASHID KHAN  ALLROUNDER            66.0
# 37   IPL00203       87.0              BEN STOKES  ALLROUNDER            82.0
# 113  IPL00197       47.0            DWAYNE BRAVO  ALLROUNDER            71.0
# 116  IPL00234       47.0           GLENN MAXWELL  ALLROUNDER            83.0
# 73   IPL00224       56.0  Rajvardhan Hangargekar  ALLROUNDER            69.0
# ...

# %%
B=data[data.ROLES=='Bowlers']
Bow= B.sort_values(['Sum_of_Rating'], ascending=[False])
Bow
# Out:
#     Player ID  Jersy No          PLAYER NAME    ROLES  Batting Rating  \
# 92   IPL00137       58.0            K.RABADA  Bowlers            68.0
# 71   IPL00150       87.0         S.Sreesanth  Bowlers            62.0
# 43   IPL00200       67.0             M.SHAMI  Bowlers            49.0
# 63   IPL00141      111.0         TRENT BOULT  Bowlers            55.0
# 97   IPL00195       11.0         TIM SOUTHEE  Bowlers            48.0
# 52   IPL00147       56.0     Dhawal Kulkarni  Bowlers            58.0
# 95   IPL00153       58.0         Sai Kishore  Bowlers            68.0
# 27   IPL00161       12.0        JOFRA ARCHER  Bowlers            60.0
# 53   IPL00201       88.0         UMESH YADAV  Bowlers            56.0
# 59   IPL00192      666.0         BHUVI KUMAR  Bowlers            51.0
# 57   IPL00126       89.0      Navdeep Saini   Bowlers            54.0
# 106  IPL00187       65.0      Sandeep Sharma  Bowlers            32.0
# ...

# %%
Bw=data[data.ROLES=='BAT/WK']
BW= Bw.sort_values(['Sum_of_Rating'], ascending=[False])
BW
# Out:
#     Player ID  Jersy No      PLAYER NAME   ROLES  Batting Rating  \
# 103  IPL00191        7.0       M.S.DHONI  BAT/WK            86.0
# 1    IPL00163       19.0  DINESH KARTHIK  BAT/WK            82.0
# 77   IPL00219       43.0        Q.DECOCK  BAT/WK            85.0
# 35   IPL00152        5.0    ISHAN KISHAN  BAT/WK            81.0
# 93   IPL00174       59.0   AMBATI RAYUDU  BAT/WK            83.0
# 90   IPL00214       33.0     JOS BUTTLER  BAT/WK            83.0
# 91   IPL00145       17.0          R.PANT  BAT/WK            85.0
# 45   IPL00144       60.0   ROBIN UTHAPPA  BAT/WK            82.0
# 56   IPL00212       48.0          W.SAHA  BAT/WK            73.0
# 26   IPL00225       37.0    SANJU SAMSON  BAT/WK            72.0
#
#      Bowling Rating  Fielding Rating  Stamina  Concentration  Agility  \
# 103             7.0            100.0     88.0           95.0     92.0
# 1               9.0             89.0     44.0           74.0     76.0
# ...

# %%
dat= pd.DataFrame(data) 
dat.to_excel("ipl.xlsx")

# %%
data.loc[data['Player ID']=='IPL001']
# Out:
#    Player ID  Jersy No       PLAYER NAME    ROLES  Batting Rating  \
# 14  IPL00199       65.0  Sheldon Jackson  Batsman            73.0
#
#     Bowling Rating  Fielding Rating  Stamina  Concentration  Agility  \
# 14             3.0             83.0     61.0           85.0     47.0
#
#     Heart rate   BMI base price       Nationality  Sum_of_Rating
# 14        81.0  20.0        50L  Uncappped Indian          159.0
